# %%
import numpy as np
import pylab
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib.ticker as mtick
# %matplotlib inline
import datetime
from datetime import date
import seaborn as sb
import time
import scipy.stats as stats
from scipy.stats import mstats
from scipy.stats import ttest_ind
from scipy import stats
import seaborn as sns
sns.set_style("whitegrid")
sns.color_palette("Set2", 10)
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
from sklearn.metrics import r2_score, mean_squared_error
import sklearn
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn import linear_model

from sklearn.decomposition import PCA 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from scipy import stats
from scipy import stats
from sklearn.model_selection import learning_curve, validation_curve
from sklearn.pipeline import Pipeline
from sklearn import metrics
import seaborn

# %%
df = pd.read_csv('/Users/ezzan/Downloads/ESSdata_Thinkful.csv')
means = df.groupby(["cntry"])["ppltrst"].mean()

df = df.dropna(how='all')

# %%
df.head()
# Out:
#   cntry  idno  year  tvtot  ppltrst  pplfair  pplhlp  happy  sclmeet  sclact  \
# 0    CH   5.0     6    3.0      3.0     10.0     5.0    8.0      5.0     4.0
# 1    CH  25.0     6    6.0      5.0      7.0     5.0    9.0      3.0     2.0
# 2    CH  26.0     6    1.0      8.0      8.0     8.0    7.0      6.0     3.0
# 3    CH  28.0     6    4.0      6.0      6.0     7.0   10.0      6.0     2.0
# 4    CH  29.0     6    5.0      6.0      7.0     5.0    8.0      7.0     2.0
#
#    gndr  agea  partner
# 0   2.0  60.0      1.0
# 1   2.0  59.0      1.0
# 2   1.0  24.0      2.0
# 3   2.0  64.0      1.0
# 4   2.0  55.0      1.0

# %% [markdown]
# In this dataset, the same participants answered questions in 2012 and again 2014.

# %% [markdown]
# ### Question 1: Did people become less trusting from 2012 to 2014? Compute results for each country in the sample.

# %%
df2012 = df[df['year'] == 6]
df2014 = df[df['year'] == 7]

# %%
plt.title('Histogram of Trust Scores, 2012')
df2012 = df2012.dropna()
sns.distplot(df2012['ppltrst'])
plt.show()
# Out:
# c:\users\ezzan\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.title('Histogram of Trust Scores, 2014')
df2014 = df2014.dropna()
sns.distplot(df2014['ppltrst'])
df.cntry = df.cntry.dropna()
plt.show()
# Out:
# c:\users\ezzan\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
g = sns.FacetGrid(df, row='year', col='cntry', dropna=True, sharey=False)
g = g.map(plt.hist, 'ppltrst', alpha=0.8)
print('\t\tTrust Distribution for Six European Countries (2012 & 2014)')
plt.show()
# Out:
# 		Trust Distribution for Six European Countries (2012 & 2014)

# %%
print('\t\tTrust Distribution for Czech (2012 & 2014)')
dfCH12 = df[(df.year == 6) & (df.cntry=='CH')][["ppltrst"]].hist()
dfCH14 = df[(df.year == 7) & (df.cntry=='CH')][["ppltrst"]].hist()
# Out:
# 		Trust Distribution for Czech (2012 & 2014)

# %%
stats.ttest_rel(df[(df.year == 6) & (df.cntry=='CH')][["ppltrst"]],df[(df.year == 7) & (df.cntry=='CH')][["ppltrst"]])
# Out:
# Ttest_relResult(statistic=array([-0.65868518]), pvalue=array([0.51029435]))

# %%
print('\t\tTrust Distribution for Norway (2012 & 2014)')
dfNO12 = df[(df.year == 6) & (df.cntry=='NO')][["ppltrst"]].hist()
dfNO14 = df[(df.year == 7) & (df.cntry=='NO')][["ppltrst"]].hist()
# Out:
# 		Trust Distribution for Norway (2012 & 2014)

# %%
stats.ttest_rel(df[(df.year == 6) & (df.cntry=='NO')][["ppltrst"]],df[(df.year == 7) & (df.cntry=='NO')][["ppltrst"]], nan_policy='omit')
# Out:
# Ttest_relResult(statistic=masked_array(data=[0.5073077081124404],
#              mask=[False],
#        fill_value=1e+20), pvalue=masked_array(data=0.61209257,
#              mask=False,
#        fill_value=1e+20))

# %%
print('\t\tTrust Distribution for Sweden (2012 & 2014)')
df[(df.year == 6) & (df.cntry=='SE')][["ppltrst"]].hist()
df[(df.year == 7) & (df.cntry=='SE')][["ppltrst"]].hist()
# Out:
# 		Trust Distribution for Sweden (2012 & 2014)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00CC51D0>]],
#       dtype=object)

# %%
stats.ttest_rel(df[(df.year == 6) & (df.cntry=='SE')][["ppltrst"]],df[(df.year == 7) & (df.cntry=='SE')][["ppltrst"]], nan_policy='omit')
# Out:
# Ttest_relResult(statistic=masked_array(data=[-2.0671082026033982],
#              mask=[False],
#        fill_value=1e+20), pvalue=masked_array(data=0.03900782,
#              mask=False,
#        fill_value=1e+20))

# %%
print('\t\tTrust Distribution for Norway (2012 & 2014)')
df[(df.year == 6) & (df.cntry=='DE')][["ppltrst"]].hist()
df[(df.year == 7) & (df.cntry=='DE')][["ppltrst"]].hist()
# Out:
# 		Trust Distribution for Norway (2012 & 2014)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11503590>]],
#       dtype=object)

# %%
stats.ttest_rel(df[(df.year == 6) & (df.cntry=='DE')][["ppltrst"]],df[(df.year == 7) & (df.cntry=='DE')][["ppltrst"]], nan_policy='omit')
# Out:
# Ttest_relResult(statistic=array([-0.18399502]), pvalue=array([0.85685638]))

# %%
print('\t\tTrust Distribution for Spain (2012 & 2014)')
df[(df.year == 6) & (df.cntry=='ES')][["ppltrst"]].hist()
df[(df.year == 7) & (df.cntry=='ES')][["ppltrst"]].hist()
# Out:
# 		Trust Distribution for Spain (2012 & 2014)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x15D0B250>]],
#       dtype=object)

# %%
stats.ttest_rel(df[(df.year == 6) & (df.cntry=='ES')][["ppltrst"]],df[(df.year == 7) & (df.cntry=='ES')][["ppltrst"]], nan_policy='omit')
# Out:
# Ttest_relResult(statistic=masked_array(data=[2.4561906976601646],
#              mask=[False],
#        fill_value=1e+20), pvalue=masked_array(data=0.01418158,
#              mask=False,
#        fill_value=1e+20))

# %% [markdown]
# ##### It appears people in SE became considerably less trusting while people in ES become signifigantly more trusting

# %% [markdown]
# ### Question 2 Did people become happier from 2012 to 2014? Compute results for each country in the sample.

# %%
g = sns.FacetGrid(df, row='year', col='cntry', dropna=True, sharey=False)
g = g.map(plt.hist, 'happy', alpha=0.8)
print('\t\tHapiness  Distribution for Six European Countries (2012 & 2014)')
plt.show()
# Out:
# 		Hapiness  Distribution for Six European Countries (2012 & 2014)

# %%
print('\t\tHappiness Distribution for Switzerland (2012 & 2014)')
df[(df.year == 6) & (df.cntry=='CH')][["happy"]].hist()
df[(df.year == 7) & (df.cntry=='CH')][["happy"]].hist()
# Out:
# 		Happiness Distribution for Switzerland (2012 & 2014)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1131F910>]],
#       dtype=object)

# %%
stats.ttest_rel(df[(df.year == 6) & (df.cntry=='CH')][["happy"]],df[(df.year == 7) & (df.cntry=='CH')][["happy"]], nan_policy='omit')
# Out:
# Ttest_relResult(statistic=masked_array(data=[-0.319412957862232],
#              mask=[False],
#        fill_value=1e+20), pvalue=masked_array(data=0.74950014,
#              mask=False,
#        fill_value=1e+20))

# %%
print('\t\tHappiness Distribution for Norway (2012 & 2014)')
df[(df.year == 6) & (df.cntry=='NO')][["happy"]].hist()
df[(df.year == 7) & (df.cntry=='NO')][["happy"]].hist()
# Out:
# 		Happiness Distribution for Norway (2012 & 2014)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14C11170>]],
#       dtype=object)

# %%
stats.ttest_rel(df[(df.year == 6) & (df.cntry=='NO')][["happy"]],df[(df.year == 7) & (df.cntry=='NO')][["happy"]], nan_policy='omit')
# Out:
# Ttest_relResult(statistic=masked_array(data=[4.2856826576235925],
#              mask=[False],
#        fill_value=1e+20), pvalue=masked_array(data=2.06745301e-05,
#              mask=False,
#        fill_value=1e+20))

# %%
print('\t\tHappiness Distribution for Denmark (2012 & 2014)')
df[(df.year == 6) & (df.cntry=='DE')][["happy"]].hist()
df[(df.year == 7) & (df.cntry=='DE')][["happy"]].hist()
# Out:
# 		Happiness Distribution for Denmark (2012 & 2014)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x148EA3F0>]],
#       dtype=object)

# %%
stats.ttest_rel(df[(df.year == 6) & (df.cntry=='DE')][["happy"]],df[(df.year == 7) & (df.cntry=='DE')][["happy"]], nan_policy='omit')
# Out:
# Ttest_relResult(statistic=array([-0.80622577]), pvalue=array([0.43461387]))

# %%
print('\t\tHappiness Distribution for Sweden (2012 & 2014)')
df[(df.year == 6) & (df.cntry=='SE')][["happy"]].hist()
df[(df.year == 7) & (df.cntry=='SE')][["happy"]].hist()
# Out:
# 		Happiness Distribution for Sweden (2012 & 2014)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11620310>]],
#       dtype=object)

# %%
stats.ttest_rel(df[(df.year == 6) & (df.cntry=='SE')][["happy"]],df[(df.year == 7) & (df.cntry=='SE')][["happy"]], nan_policy='omit')
# Out:
# Ttest_relResult(statistic=masked_array(data=[-0.5581637086030012],
#              mask=[False],
#        fill_value=1e+20), pvalue=masked_array(data=0.57687096,
#              mask=False,
#        fill_value=1e+20))

# %%
print('\t\tHappiness Distribution for Spain (2012 & 2014)')
df[(df.year == 6) & (df.cntry=='ES')][["happy"]].hist()
df[(df.year == 7) & (df.cntry=='ES')][["happy"]].hist()
# Out:
# 		Happiness Distribution for Spain (2012 & 2014)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12DE9290>]],
#       dtype=object)

# %%
stats.ttest_rel(df[(df.year == 6) & (df.cntry=='ES')][["happy"]],df[(df.year == 7) & (df.cntry=='ES')][["happy"]], nan_policy='omit')
# Out:
# Ttest_relResult(statistic=masked_array(data=[1.613832417735418],
#              mask=[False],
#        fill_value=1e+20), pvalue=masked_array(data=0.10682452,
#              mask=False,
#        fill_value=1e+20))

# %% [markdown]
# ##### Nobody became signifigantly happier except except for Spain and Sweden

# %% [markdown]
# ### Question 3: Who reported watching more TV in 2012, men or women?

# %%
m2012 = df[df['gndr'] == 1]
f2012 = df[df['gndr'] == 2]
mentv = df[(df.year == 6) & (df.gndr== 1)][["tvtot"]].hist()
plt.title('Histogram of TV Total for Males, 2012')
plt.show()
femtv = df[(df.year == 6) & (df.gndr== 2)][["tvtot"]].hist()
plt.title('Histogram of TV Total for Females, 2012')
plt.show()
sns.set(style="darkgrid")

g = sns.factorplot(x="gndr", y="tvtot", data = df2012,
                   size=5, kind="bar", palette="pastel", ci=None)
g.despine(left=True)
g.set_ylabels("Hours of TV Watched")
g.set_xlabels("Gender")
plt.title('TV Total (2012)')
# Out:
# Text(0.5,1,'TV Total (2012)')

# %%
m2012 = m2012.dropna()
sns.distplot(m2012['tvtot'])
# Out:
# c:\users\ezzan\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
f2012 = f2012.dropna()
sns.distplot(f2012['tvtot'])
# Out:
# c:\users\ezzan\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
stats.kruskal(
     m2012['tvtot'],
     f2012['tvtot'])
# Out:
# KruskalResult(statistic=2.7294759657508987, pvalue=0.0985116036112953)

# %%
stats.mannwhitneyu(m2012['tvtot'], f2012['tvtot'], use_continuity=True, alternative='two-sided')
# Out:
# MannwhitneyuResult(statistic=9031681.5, pvalue=0.11578017930588337)

# %%
mentv = df[(df.year == 6) & (df.gndr== 1)][["tvtot"]]
femtv = df[(df.year == 6) & (df.gndr== 2)][["tvtot"]]
print(stats.ttest_ind(mentv, femtv,nan_policy='omit'))
# Out:
# Ttest_indResult(statistic=masked_array(data=[-0.6899928109209502],
#              mask=[False],
#        fill_value=1e+20), pvalue=masked_array(data=0.49023604,
#              mask=False,
#        fill_value=1e+20))

# %% [markdown]
# #### With a p vaue more than .05 we will not reject null hypothesis and there is no signifigant difference between two samples.

# %% [markdown]
# ### Question 4:  Who was more likely to believe people were fair in 2012, people living with a partner or people living alone?

# %%
part2012 = df2012[df2012['partner'] == 1]
sing2012 = df2012[df2012['partner'] == 2]
part2012 = part2012.dropna()
sing2012 = sing2012.dropna()

# %%
sns.distplot(part2012['pplfair'])
# Out:
# c:\users\ezzan\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(sing2012['pplfair'])
# Out:
# c:\users\ezzan\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
part2012 = df['pplfair'][(df['partner'] == 1.0) & (df['year'] == 6)]
sing2012 = df['pplfair'][(df['partner'] == 2.0) & (df['year'] == 6)]

# %%
print('Lives with partner mean:{0:.2f}'.format(part2012.mean()))
print('Lives alone mean: {0:.2f}'.format(sing2012.mean()))  
print(stats.ttest_ind(part2012, 
                    sing2012,
                    nan_policy='omit'
                    ))
# Out:
# Lives with partner mean:6.08
# Lives alone mean: 5.86
# Ttest_indResult(statistic=3.3201033970362084, pvalue=0.0009073952609876207)

# %% [markdown]
# #### The t test suggests there is a signifigant difference with a pvalue of .0009

# %% [markdown]
# ##### People living with a partner were more likely to believe people were fair in 2012 than those living alone.

# %% [markdown]
# ### Question 5: Pick three or four of the countries in the sample and compare how often people met socially in 2014. Are there differences, and if so, which countries stand out?

# %%
ax = sns.boxplot(x="cntry", y="sclmeet", hue="cntry", data=df2012) 
plt.title("sclmeet scores Boxplot by Country")
plt.show()

# %%
denmark = df2014['sclmeet'][(df2014['cntry'] == 'DE') & (df2014['year'] == 7)].dropna()
norway = df2014['sclmeet'][(df2014['cntry'] == 'NO') & (df2014['year'] == 7)].dropna()
spain = df2014['sclmeet'][(df2014['cntry'] == 'ES') & (df2014['year'] == 7)].dropna()

# %%
sns.distplot(denmark)
# Out:
# c:\users\ezzan\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(norway)
# Out:
# c:\users\ezzan\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(spain)
# Out:
# c:\users\ezzan\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
F, p = stats.f_oneway(spain, denmark, norway)
print('F statistic:', F, '\np-value:', p)
# Out:
# F statistic: 2.8278064817149695
# p-value: 0.059397147741555786

# %% [markdown]
# #### Since the p-value is less than 0.05, we reject the null hypothesis that there's no difference between the means and conclude that a significant difference does exist

# %%
print('T Test Results for Norway, Sweden and Estonia\n')
print('Spain-Norway:', stats.ttest_ind(spain, norway))
print('Spain Denmark:', stats.ttest_ind(spain, denmark))
print('Denmark Norway:', stats.ttest_ind(denmark, norway))
# Out:
# T Test Results for Norway, Sweden and Estonia
#
# Spain-Norway: Ttest_indResult(statistic=-0.6968046493592841, pvalue=0.48601288469157433)
# Spain Denmark: Ttest_indResult(statistic=2.168865565712128, pvalue=0.030298013218196748)
# Denmark Norway: Ttest_indResult(statistic=-2.4461487954484564, pvalue=0.014676088277028508)

# %% [markdown]
# #### There appears to be signifigance between the means of Spain and Denmark (pvalue = .0302) and between Denmark and Norway (pvalue = .01467)

# %% [markdown]
# ### Pick three or four of the countries in the sample and compare how often people took part in social activities, relative to others their age, in 2014. Are there differences, and if so, which countries stand out?

# %%
spainsocial = df['sclact'][(df['year'] == 7) & (df['cntry'] == 'ES')].dropna()
norwaysocial= df['sclact'][(df['year'] == 7) & (df['cntry'] == 'NO') ].dropna()
denmarksocial = df['sclact'][(df['year'] == 7) & (df['cntry'] == 'DE')].dropna()
plt.hist(spainsocial)
plt.show()

# %%
plt.hist(denmarksocial)
plt.show()

# %%
plt.hist(norwaysocial)
plt.show()

# %%
df[(df.year == 7) & (df.cntry=='ES')& (df.agea < 20)][["sclact"]].hist()
df[(df.year == 7) & (df.cntry=='ES')& (df.agea > 20) & (df.agea < 30)][["sclact"]].hist()
df[(df.year == 7) & (df.cntry=='ES')& (df.agea > 30) & (df.agea < 40)][["sclact"]].hist()
df[(df.year == 7) & (df.cntry=='ES')& (df.agea > 40) & (df.agea < 50)][["sclact"]].hist()
df[(df.year == 7) & (df.cntry=='ES')& (df.agea > 50) & (df.agea < 60)][["sclact"]].hist()
df[(df.year == 7) & (df.cntry=='ES')& (df.agea > 60) & (df.agea < 70)][["sclact"]].hist()
df[(df.year == 7) & (df.cntry=='ES')& (df.agea > 70) & (df.agea < 80)][["sclact"]].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x115460D0>]],
#       dtype=object)

# %%
df[(df.year == 7) & (df.cntry=='DE')& (df.agea < 20)][["sclact"]].hist()
df[(df.year == 7) & (df.cntry=='DE')& (df.agea > 20) & (df.agea < 30)][["sclact"]].hist()
df[(df.year == 7) & (df.cntry=='DE')& (df.agea > 30) & (df.agea < 40)][["sclact"]].hist()
df[(df.year == 7) & (df.cntry=='DE')& (df.agea > 40) & (df.agea < 50)][["sclact"]].hist()
df[(df.year == 7) & (df.cntry=='DE')& (df.agea > 50) & (df.agea < 60)][["sclact"]].hist()
df[(df.year == 7) & (df.cntry=='DE')& (df.agea > 60) & (df.agea < 70)][["sclact"]].hist()
df[(df.year == 7) & (df.cntry=='DE')& (df.agea > 70) & (df.agea < 80)][["sclact"]].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12DBB6F0>]],
#       dtype=object)

# %%
df[(df.year == 7) & (df.cntry=='NO')& (df.agea < 20)][["sclact"]].hist()
df[(df.year == 7) & (df.cntry=='NO')& (df.agea > 20) & (df.agea < 30)][["sclact"]].hist()
df[(df.year == 7) & (df.cntry=='NO')& (df.agea > 30) & (df.agea < 40)][["sclact"]].hist()
df[(df.year == 7) & (df.cntry=='NO')& (df.agea > 40) & (df.agea < 50)][["sclact"]].hist()
df[(df.year == 7) & (df.cntry=='NO')& (df.agea > 50) & (df.agea < 60)][["sclact"]].hist()
df[(df.year == 7) & (df.cntry=='NO')& (df.agea > 60) & (df.agea < 70)][["sclact"]].hist()
df[(df.year == 7) & (df.cntry=='NO')& (df.agea > 70) & (df.agea < 80)][["sclact"]].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1124ABB0>]],
#       dtype=object)

# %%
F, p = stats.f_oneway(spainsocial, denmarksocial, norwaysocial)
print('F statistic:', F, '\np-value:', p)
# Out:
# F statistic: 16.1203746579285
# p-value: 1.1400714087533104e-07

# %%
print('Spain-Norway:', stats.ttest_ind(spainsocial, norwaysocial))
print('Spain Denmark:', stats.ttest_ind(spainsocial, denmarksocial))
print('Denmark Norway:', stats.ttest_ind(denmarksocial, norwaysocial))
# Out:
# Spain-Norway: Ttest_indResult(statistic=-5.671149129663532, pvalue=1.6345881270312057e-08)
# Spain Denmark: Ttest_indResult(statistic=-0.3809408460233457, pvalue=0.7033147402370797)
# Denmark Norway: Ttest_indResult(statistic=-0.6482404208916689, pvalue=0.517029737677969)

# %% [markdown]
# #### It appears none of these produced signifigant changes in terms of social activity.
